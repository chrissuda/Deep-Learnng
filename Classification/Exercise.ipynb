# %%
import torch

# %%
# Out:
# ...
# ---------------------------------------------------------------------------
# DownloadError                             Traceback (most recent call last)
# <ipython-input-9-139c80e99ecf> in <module>
#       4     split=['train', 'test'],
#       5     batch_size=-1,
# ----> 6     as_supervised=True,
#       7 ))
#       8 print(x_train.shape)
#
# ~\AppData\Roaming\Python\Python37\site-packages\wrapt\wrappers.py in __call__(self, *args, **kwargs)
#     562
#     563         return self._self_wrapper(self.__wrapped__, self._self_instance,
# --> 564                 args, kwargs)
#     565
#     566 class BoundFunctionWrapper(_FunctionWrapperBase):
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow_datasets\core\api_utils.py in disallow_positional_args_dec(fn, instance, args, kwargs)
#      50     _check_no_positional(fn, args, ismethod, allowed=allowed)
#      51     _check_required(fn, kwargs)
# ---> 52     return fn(*args, **kwargs)
#      53
# ...
